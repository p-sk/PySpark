# %% [markdown]
# Kaggle link: https://www.kaggle.com/ntnu-testimon/paysim1
#
# ##Data Dcitonry
#
# | Colomn          | Discription                                                                                                                                                                                                                                                                                                    |
# |-----------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | step            |  maps a unit of time in the real   world. In this case 1 step is 1 hour of time. Total steps 744 (30 days   simulation).                                                                                                                                                                                       |
# | type            |  CASH IN, CASH OUT, DEBIT, PAYMENT   and TRANSFER.                                                                                                                                                                                                                                                             |
# | amount          |  amount of the transaction in local   currency.                                                                                                                                                                                                                                                                |
# | nameOrig        |  customer who started the   transaction                                                                                                                                                                                                                                                                        |
# | oldbalanceOrg   |  initial balance before the   transaction                                                                                                                                                                                                                                                                      |
# | newbalanceOrig  |  new balance after the transaction                                                                                                                                                                                                                                                                             |
# | nameDest        |  customer who is the recipient of   the transaction                                                                                                                                                                                                                                                            |
# | oldbalanceDest  |  initial balance recipient before   the transaction. Note that there is not information for customers that start   with M (Merchants).                                                                                                                                                                         |
# | newbalanceDest  |  new balance recipient after the   transaction. Note that there is not information for customers that start with   M (Merchants).                                                                                                                                                                              |
# | isFraud         |  This is the transactions made by   the fraudulent agents inside the simulation. In this specific dataset the   fraudulent behavior of the agents aims to profit by taking control or   customers accounts and try to empty the funds by transferring to another   account and then cashing out of the system. |
# | isFlaggedFraud  |  The business model aims to control   massive transfers from one account to another and flags illegal attempts. An   illegal attempt in this dataset is an attempt to transfer more than 200.000   in a single transaction.                                                                                    |

# %%
from pyspark.sql import SparkSession 
spark = SparkSession.builder \
    .master("local") \
    .appName("Word Count") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# File location and type
file_location = "/FileStore/tables/dataset.csv"
file_type = "csv"

# CSV options
first_row_is_header = "True"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>step</th><th>type</th><th>amount</th><th>nameOrig</th><th>oldbalanceOrg</th><th>newbalanceOrig</th><th>nameDest</th><th>oldbalanceDest</th><th>newbalanceDest</th><th>isFraud</th><th>isFlaggedFraud</th></tr></thead><tbody><tr><td>1</td><td>PAYMENT</td><td>9839.64</td><td>C1231006815</td><td>170136.0</td><td>160296.36</td><td>M1979787155</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>1864.28</td><td>C1666544295</td><td>21249.0</td><td>19384.72</td><td>M2044282225</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>TRANSFER</td><td>181.0</td><td>C1305486145</td><td>181.0</td><td>0.0</td><td>C553264065</td><td>0.0</td><td>0.0</td><td>1</td><td>0</td></tr><tr><td>1</td><td>CASH_OUT</td><td>181.0</td><td>C840083671</td><td>181.0</td><td>0.0</td><td>C38997010</td><td>21182.0</td><td>0.0</td><td>1</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>11668.14</td><td>C2048537720</td><td>41554.0</td><td>29885.86</td><td>M1230701703</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>7817.71</td><td>C90045638</td><td>53860.0</td><td>46042.29</td><td>M573487274</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>7107.77</td><td>C154988899</td><td>183195.0</td><td>176087.23</td><td>M408069119</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>7861.64</td><td>C1912850431</td><td>176087.23</td><td>168225.59</td><td>M633326333</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>4024.36</td><td>C1265012928</td><td>2671.0</td><td>0.0</td><td>M1176932104</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>DEBIT</td><td>5337.77</td><td>C712410124</td><td>41720.0</td><td>36382.23</td><td>C195600860</td><td>41898.0</td><td>40348.79</td><td>0</td><td>0</td></tr><tr><td>1</td><td>DEBIT</td><td>9644.94</td><td>C1900366749</td><td>4465.0</td><td>0.0</td><td>C997608398</td><td>10845.0</td><td>157982.12</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>3099.97</td><td>C249177573</td><td>20771.0</td><td>17671.03</td><td>M2096539129</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>2560.74</td><td>C1648232591</td><td>5070.0</td><td>2509.26</td><td>M972865270</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>11633.76</td><td>C1716932897</td><td>10127.0</td><td>0.0</td><td>M801569151</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>4098.78</td><td>C1026483832</td><td>503264.0</td><td>499165.22</td><td>M1635378213</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>CASH_OUT</td><td>229133.94</td><td>C905080434</td><td>15325.0</td><td>0.0</td><td>C476402209</td><td>5083.0</td><td>51513.44</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>1563.82</td><td>C761750706</td><td>450.0</td><td>0.0</td><td>M1731217984</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>1157.86</td><td>C1237762639</td><td>21156.0</td><td>19998.14</td><td>M1877062907</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>671.64</td><td>C2033524545</td><td>15123.0</td><td>14451.36</td><td>M473053293</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>TRANSFER</td><td>215310.3</td><td>C1670993182</td><td>705.0</td><td>0.0</td><td>C1100439041</td><td>22425.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>PAYMENT</td><td>1373.43</td><td>C20804602</td><td>13854.0</td><td>12480.57</td><td>M1344519051</td><td>0.0</td><td>0.0</td><td>0</td><td>0</td></tr><tr><td>1</td><td>DEBIT</td><td>9302.79</td><td>C1566511282</td><td>11299.0</td><td>1996.21</td><td>C1973538135</td><td>29832.0</td><td>16896.7</td><td>0</td><td> ...

# %%
from pyspark.sql.types import FloatType,IntegerType
numericCols = ['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest','isFlaggedFraud']
for i in numericCols:
  df = df.withColumn(i, df[i].cast(FloatType()))
df = df.withColumn("label", df['isFraud'].cast(IntegerType()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Printing schema of dataframe 
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- step: string (nullable = true)
# -- type: string (nullable = true)
# -- amount: float (nullable = true)
# -- nameOrig: string (nullable = true)
# -- oldbalanceOrg: float (nullable = true)
# -- newbalanceOrig: float (nullable = true)
# -- nameDest: string (nullable = true)
# -- oldbalanceDest: float (nullable = true)
# -- newbalanceDest: float (nullable = true)
# -- isFraud: string (nullable = true)
# -- isFlaggedFraud: float (nullable = true)
# -- label: integer (nullable = true)
#
# </div>

# %%
# Create a view or table
table_name = "dataset"

df.createOrReplaceTempView(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
-- Organize by Type
select type, count(isFraud) from dataset group by type
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>type</th><th>count(isFraud)</th></tr></thead><tbody><tr><td>TRANSFER</td><td>532909</td></tr><tr><td>CASH_IN</td><td>1399284</td></tr><tr><td>CASH_OUT</td><td>2237500</td></tr><tr><td>PAYMENT</td><td>2151495</td></tr><tr><td>DEBIT</td><td>41432</td></tr></tbody></table></div>

# %%
# %sql

select type, count(type) from dataset group by type
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>type</th><th>count(type)</th></tr></thead><tbody><tr><td>TRANSFER</td><td>532909</td></tr><tr><td>CASH_IN</td><td>1399284</td></tr><tr><td>CASH_OUT</td><td>2237500</td></tr><tr><td>PAYMENT</td><td>2151495</td></tr><tr><td>DEBIT</td><td>41432</td></tr></tbody></table></div>

# %%
# %sql 


select nameOrig,sum(amount) as amount from dataset group by nameOrig
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nameOrig</th><th>amount</th></tr></thead><tbody><tr><td>C1305004711</td><td>8586.98046875</td></tr><tr><td>C1016856028</td><td>1795.6700439453125</td></tr><tr><td>C1215951090</td><td>14306.7998046875</td></tr><tr><td>C32393008</td><td>5485.0400390625</td></tr><tr><td>C1298380324</td><td>107292.25</td></tr><tr><td>C577245010</td><td>139754.71875</td></tr><tr><td>C2028036437</td><td>60503.37109375</td></tr><tr><td>C1298557761</td><td>6778.31982421875</td></tr><tr><td>C684230144</td><td>210650.203125</td></tr><tr><td>C990684641</td><td>33349.83984375</td></tr><tr><td>C569976699</td><td>885.9500122070312</td></tr><tr><td>C1434932926</td><td>2976.860107421875</td></tr><tr><td>C143999341</td><td>5206.22998046875</td></tr><tr><td>C1232948374</td><td>2391.3798828125</td></tr><tr><td>C355222677</td><td>53083.58984375</td></tr><tr><td>C840042838</td><td>1094.1300048828125</td></tr><tr><td>C1288163341</td><td>194242.453125</td></tr><tr><td>C339881373</td><td>17694.759765625</td></tr><tr><td>C1112569408</td><td>7536.31005859375</td></tr><tr><td>C1393484427</td><td>71758.1015625</td></tr><tr><td>C748673892</td><td>342332.5625</td></tr><tr><td>C1809269661</td><td>6324.02978515625</td></tr><tr><td>C413168155</td><td>137497.96875</td></tr><tr><td>C363103401</td><td>7237.740234375</td></tr><tr><td>C185876853</td><td>50738.94140625</td></tr><tr><td>C1566238378</td><td>27241.7890625</td></tr><tr><td>C1860205951</td><td>9455.400390625</td></tr><tr><td>C336141860</td><td>8818.98046875</td></tr><tr><td>C376961419</td><td>3107.719970703125</td></tr><tr><td>C817880261</td><td>2518.6298828125</td></tr><tr><td>C1501084178</td><td>10808.400390625</td></tr><tr><td>C2089976729</td><td>133988.453125</td></tr><tr><td>C938539778</td><td>104427.8671875</td></tr><tr><td>C1916150078</td><td>3209.510009765625</td></tr><tr><td>C406074816</td><td>3774.030029296875</td></tr><tr><td>C678565780</td><td>210269.65625</td></tr><tr><td>C336982413</td><td>1970.72998046875</td></tr><tr><td>C1627993706</td><td>840288.0625</td></tr><tr><td>C547293574</td><td>191490.234375</td></tr><tr><td>C2111384118</td><td>10446.6298828125</td></tr><tr><td>C1122185195</td><td>66345.421875</td></tr><tr><td>C1700614789</td><td>1349.3800048828125</td></tr><tr><td>C976451032</td><td>9782.98046875</td></tr><tr><td>C491457031</td><td>127408.6484375</td></tr><tr><td>C936706583</td><td>30030.439453125</td></tr><tr><td>C852337468</td><td>738.02001953125</td></tr><tr><td>C1585430546</td><td>758.6099853515625</td></tr><tr><td>C626183040</td><td>143860.3125</td></tr><tr><td>C131646052</td><td>223559.65625</td></tr><tr><td>C543835743</td><td>11045.6103515625</td></tr><tr><td>C1834895023</td><td>6691.68994140625</td></tr><tr><td>C282508229</td><td>11286.240234375</td></tr><tr><td>C783262297</td><td>8076.490234375</td></tr><tr><td>C1637956318</td><td>354667.875</td></tr><tr><td>C1846358244</td><td>4771.14990234375</td></tr><tr><td>C326207642</td><td>17245.640625</td></tr><tr><td>C1739894898</td><td>234439.40625</td></tr><tr><td>C1868569824</td><td>6565.7099609375</td></tr><tr><td>C59792230</td><td>269956.59375</td></tr><tr><td>C54609068</td><td>18509.830078125</td></tr><tr><td>C1859447501</td><td>187786.453125</td></tr><tr><td>C371664616</td><td>5075.08984375</td></tr><tr><td>C798475098</td><td>269032.53125</td></tr><tr><td>C40931593</td><td>602720.75</td></tr><tr><td>C64351703</td><td>1358.9200439453125</td></tr><tr><td>C184527176</td><td>1436.280029296875</td></tr><tr><td>C1563408461</td><td>1816.4100341796875</td></tr><tr><td>C318043732</td><td>5700.16015625</td></tr><tr><td>C2026365267</td><td>345357.46875</td></tr><tr><td>C279519413</td><td>1295720.5</td></tr><tr><td>C1588474866</td><td>13008.259765625</td></tr><tr><td>C240995764</td><td>67339.7421875</td></tr><tr><td>C1458646266</td><td>1207.5699462890625</td></tr><tr><td>C1182135728</td><td>285810.875</td></tr><tr><td>C173212708</ ...

# %%
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler

categoricalCol = 'type'
stages = []
#Indexing each category 
stringIndexer = StringIndexer(inputCol = categoricalCol, outputCol = categoricalCol + 'out')

encoder = OneHotEncoderEstimator(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "Vec"])
stages += [stringIndexer, encoder]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest','isFlaggedFraud'].describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>amount</th><th>oldbalanceOrg</th><th>newbalanceOrig</th><th>oldbalanceDest</th><th>newbalanceDest</th><th>isFlaggedFraud</th></tr></thead><tbody><tr><td>count</td><td>6362620</td><td>6362620</td><td>6362620</td><td>6362620</td><td>6362620</td><td>6362620</td></tr><tr><td>mean</td><td>179861.90355799918</td><td>833883.1040482764</td><td>855113.6685519267</td><td>1100701.6665156619</td><td>1224996.398184313</td><td>2.51468734577894E-6</td></tr><tr><td>stddev</td><td>603858.2316772771</td><td>2888242.672998957</td><td>2924048.5029103346</td><td>3399180.111757725</td><td>3674128.941013774</td><td>0.0015857747057365543</td></tr><tr><td>min</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>max</td><td>9.244552E7</td><td>5.958504E7</td><td>4.958504E7</td><td>3.56015904E8</td><td>3.56179264E8</td><td>1.0</td></tr></tbody></table></div>

# %%
assemblerInputs = [categoricalCol + "Vec"] + numericCols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="assemblerfeatures")
stages += [assembler]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.feature import StandardScaler

scaler = StandardScaler(inputCol="assemblerfeatures", outputCol="features",
                        withStd=True, withMean=False)
stages += [scaler]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml import Pipeline

pipeline = Pipeline(stages = stages)

pipelineModel = pipeline.fit(df)
df = pipelineModel.transform(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.select('features','label'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>features</th><th>label</th></tr></thead><tbody><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.016294618723846643, 0.05890640755035333, 0.054820006992174194))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.003087280973414316, 0.007357068780490067, 0.006629411476530337))</td><td>0</td></tr><tr><td>List(0, 10, List(3, 4, 5), List(3.6098230343966917, 2.9973922769464275E-4, 6.266786433567236E-5))</td><td>1</td></tr><tr><td>List(0, 10, List(0, 4, 5, 7), List(2.094286710124407, 2.9973922769464275E-4, 6.266786433567236E-5, 0.006231502686995524))</td><td>1</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.01932264733069556, 0.014387295218809555, 0.010220712599416357))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.012946267105149845, 0.018648017531045932, 0.01574607569493938))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.01177059390212946, 0.0634278420274779, 0.06022035345848051))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.013019016259631401, 0.06096691113290742, 0.05753173847238322))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5), List(2.113813733225063, 0.006664412102562222, 9.247837880695076E-4))</td><td>0</td></tr><tr><td>List(0, 10, List(4, 5, 6, 7, 8), List(0.008839442338485718, 0.014444769613725143, 0.01244241688622423, 0.012325913491631502, 0.010981865282976904))</td><td>0</td></tr><tr><td>List(0, 10, List(4, 5, 7, 8), List(0.015972193345609762, 0.0015459227307114758, 0.0031904752450413777, 0.0429985249664125))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.005133605551906845, 0.007191570221636744, 0.00604334342583133))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.004240631088395793, 0.0017553926639881706, 8.581458232543508E-4))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5), List(2.113813733225063, 0.019265713631676493, 0.0035062843211456024))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.0067876524159842435, 0.17424574628192163, 0.17071030738825949))</td><td>0</td></tr><tr><td>List(0, 10, List(0, 4, 5, 7, 8), List(2.094286710124407, 0.37944988654631234, 0.005305994590851818, 0.0014953605966385728, 0.014020586167026606))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5), List(2.113813733225063, 0.0025897137179787914, 1.5580408260250036E-4))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.0019174367833580536, 0.00732486927008555, 0.006839195931632385))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.001112247841323432, 0.005236055869328029, 0.0049422437203688685))</td><td>0</td></tr><tr><td>List(0, 10, List(3, 4, 5, 7), List(3.6098230343966917, 0.3565576911603135, 2.440930627439172E-4, 0.006597179102817233))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.0022744246607288845, 0.004796688356388978, 0.004268250099161503))</td><td>0</td></tr><tr><td>List(0, 10, List(4, 5, 6, 7, 8), List(0.015405586197314967, 0.003912067398501448, 6.826870207353486E-4, 0.008776233979721012, 0.004598831312133474))</td><td>0</td></tr><tr><td>List(0, 10, List(4, 5, 6, 7), List(0.001764338015597472, 6.291022624194292E-4, 2.570374691484798E-4, 0.003038968121832866))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5, 6), List(2.113813733225063, 0.006419403940792939, 0.023492485806099677, 0.021879113763015514))</td><td>0</td></tr><tr><td>List(0, 10, List(3, 4, 5, 7, 8), List(3.6098230343966917, 0.516157367159276, 0.0037514160777735363, 0.0018436798857237725, 0.7400864378074088))</td><td>0</td></tr><tr><td>List(0, 10, List(1, 4, 5), List(2.113813733225063, 0.010037339171442757, 1.533804635397948E-4))</td><td>0</td></tr><tr>< ...

# %%
(train, test) = df.select('features','label').randomSplit([0.8, 0.2], seed=12345)

# Cache the training and test datasets
train.cache()
test.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[108]: DataFrame[features: vector, label: int]</div>

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.classification import GBTClassifier

gbt = GBTClassifier(featuresCol='features',labelCol='label',maxIter=10)

evaluator = BinaryClassificationEvaluator()
paramGrid = ParamGridBuilder().build()
crossVal = CrossValidator(
    estimator=gbt, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=7)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gbtModel = crossVal.fit(train)
predictions = gbtModel.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auc_roc = SVMModel.avgMetrics[0]
print("AUC ROC of Model:"+str(auc_roc))
